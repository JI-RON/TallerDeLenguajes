# %% [markdown]
# # Actividad 3
#
# En los [lineamientos](https://docs.google.com/document/d/1Zx0ow7Lk-d5lUDW_egM0LdQoFS4-SxLRRkq0mJZgGRw/edit?usp=sharing) dados para resolver esta actividad también se encuentra un enlace a la [grilla](https://docs.google.com/spreadsheets/d/1VNbFLX1ugiLGg4IGuLzlZw_QGnj3nyOCcDHcH42K-LM/edit?gid=937426456#gid=937426456) con la que será calificada.
#
# Para realizar el ejercicio deben descargar el archivo denominado [logs_catedra.csv]() y ubicarlo en una carpeta denomina **"archivos"**. Es decir que tendrán una estructura similar a:
#
# <center>
# <img src="estructura_de_archivos.png" alt="Estructura de archivos de la actividad" style="width:350px;"/>
# </center>
#
#
# Este archivo  contiene el registro de accesos al entorno catedras.linti correspondiente al curso.

# %% [markdown]
# ## Enunciado a evaluar

# %% [markdown]
# **EJERCICIO 1.** Escribir una función que retorne los usuarios que realizaron la actividad 1 de Python plus correpondiente al turno de la mañana desde una IP de la facultad. Esta función recibe un parámetro opcional que indica si los nombres de usuario se muestran en mayúsculas **("M")**, minúsculas **("m")** o como aparecen en el dataset **(None)**. Por defecto la función muestra tal como aparecen en el dataset.
#
# **NOTA:** la información sobre la actividad 1 de Python plus  se obtiene  verificando que la columna  "Nombre evento" contenga el texto "Intento de cuestionario actualizado"  y la columna "Contexto del evento" contenga el texto "Cuestionario: ACT 1  - INFO - Turno MAÑANA".
#
# Las direcciones IP de la facultad comienza con "163.10"
#
# **EJERCICIO 2.** Utilizando la función anterior, escribir un programa que ingrese desde el teclado un menú de opciones que permita mostrar los usuarios que realizaron la actividad 1 de Python plus desde una IP de la facultad con los nombres en mayúsculas, minúsculas o tal como aparecen en el dataset.

# %% [markdown]
# ### Solución a analizar
#
# **EJERCICIO 1**

# %%
import sys
import os
import csv 
from pathlib import Path 

sys.path.append(os.path.abspath(".."))
archivo = Path.cwd()/'archivo'/'logs_catedra.csv'

def usuarios_act1_turno_mañana(reader, formato=None):
    """Función que retorna todos los usuarios que realizaron la actividad 1 (act1)
    correspondiente al turno mañana, desde una IP de la facultad.
    
    Parámetros:
    - reader: Un objeto csv.DictReader con los datos ya cargados.
    - formato (opcional): Indica cómo mostrar los nombres de usuario:
      - "M" para mayúsculas,
      - "m" para minúsculas,
      - None para tal como aparece en el dataset.
      
    Retorna:
    - Una lista de usuarios que cumplan las condiciones."""
    
    usuarios = []  # Lista donde almacenaremos los nombres de los usuarios
    
    # Recorremos cada fila del archivo
    for fila in reader:
        evento = fila["Nombre evento"].lower()
        contexto = fila["Contexto del evento"].lower()
        ip = fila["Dirección IP"]

        # Verificamos si el "nombre evento" contiene "curso visto"
        # y si la "dirección IP" empieza con "163.10" (dirección de la facultad)
        if "curso visto" in evento and ip.startswith("163.10"):
            
            # Obtenemos el nombre de usuario
            usuario = fila["Nombre completo del usuario"]
            
            # Si el parámetro formato es "M", convertimos el nombre de usuario a mayúsculas
            if formato == "M":
                usuario = usuario.upper()
            # Si el parámetro formato es "m", convertimos el nombre de usuario a minúsculas
            elif formato == "m":
                usuario = usuario.lower()
            
            # Agregamos el nombre de usuario a la lista de usuarios
            usuarios.append(usuario)
    
    # Retornamos la lista de usuarios
    return usuarios

with open(archivo, encoding="utf-8") as file:
    reader = csv.DictReader(file, delimiter=",")

     # Llamamos a la función con el reader (el contenido del archivo) y el formato
    usuarios = usuarios_act1_turno_mañana(reader, formato="m")  # Puedes cambiar "M" a "m" o None
    
# Imprimimos los resultados
print("Usuarios que realizaron la act1 turno mañana desde una IP de la facultad:")
for usuario in usuarios:
    print(usuario)

# %%
import csv
from pathlib import Path
from collections import Counter
from datetime import datetime 

def mas_popular(csv_reader, modo=None):
    users = filter(lambda x:  es_nocturno(x["Hora"]), csv_reader)
    return Counter( map(lambda x: x['Nombre completo del usuario'], users)).most_common(1)

# %% [markdown]
# **EJERCICIO 2**

# %%
import sys
import os
import csv 
from pathlib import Path 

def usuarios_act1_turno_mañana(reader, formato=None):
    """Función que retorna todos los usuarios que realizaron la actividad 1 (act1)
    correspondiente al turno mañana, desde una IP de la facultad.
    
    Parámetros:
    - reader: Un objeto csv.DictReader con los datos ya cargados.
    - formato (opcional): Indica cómo mostrar los nombres de usuario:
      - "M" para mayúsculas,
      - "m" para minúsculas,
      - None para tal como aparece en el dataset.
      
    Retorna:
    - Una lista de usuarios que cumplan las condiciones."""
    
    usuarios = []  # Lista donde almacenaremos los nombres de los usuarios
    
    # Recorremos cada fila del archivo
    for fila in reader:
        evento = fila["Nombre evento"].lower()
        contexto = fila["Contexto del evento"].lower()
        ip = fila["Dirección IP"]

        # Verificamos si el "nombre evento" contiene "curso visto"
        # y si la "dirección IP" empieza con "163.10" (dirección de la facultad)
        if "curso visto" in evento and ip.startswith("163.10"):
            
            # Obtenemos el nombre de usuario
            usuario = fila["Nombre completo del usuario"]
            
            # Si el parámetro formato es "M", convertimos el nombre de usuario a mayúsculas
            if formato == "M":
                usuario = usuario.upper()
            # Si el parámetro formato es "m", convertimos el nombre de usuario a minúsculas
            elif formato == "m":
                usuario = usuario.lower()
            
            # Agregamos el nombre de usuario a la lista de usuarios
            usuarios.append(usuario)
    
    
    return usuarios


# Función para mostrar el menú de opciones y obtener la elección del usuario
def menu():
    sys.path.append(os.path.abspath(".."))
    archivo = Path.cwd()/'archivo'/'logs_catedra.csv'
    
    with open(archivo, encoding="utf-8") as file:
        reader = csv.DictReader(file, delimiter=",")

        print("\nMenú de opciones:")
        print("1. Mostrar nombres en MAYÚSCULAS")
        print("2. Mostrar nombres en minúsculas")
        print("3. Mostrar nombres tal como aparecen en el dataset")
        print("4. Salir")
            
        opcion = input("Seleccione una opción (1-4): ")
            
        if opcion == "1":
            usuarios = usuarios_act1_turno_mañana(reader, formato="M")
            print("\nUsuarios con nombres en MAYÚSCULAS:")
        elif opcion == "2":
            usuarios = usuarios_act1_turno_mañana(reader, formato="m")
            print("\nUsuarios con nombres en minúsculas:")
        elif opcion == "3":
            usuarios = usuarios_act1_turno_mañana(reader, formato=None)
            print("\nUsuarios con nombres tal como aparecen en el dataset:")
        elif opcion == "4":
            print("¡Hasta luego!")
            return  
        else:
            print("Opción inválida.seleccione una opción entre 1 y 4.")
            return 

        # Imprimimos los usuarios que cumplieron las condiciones
        if usuarios:
            for usuario in usuarios:
                print(usuario)
        else:
            print("No se encontraron usuarios que cumplan las condiciones.")

# Bloque principal (main) del programa
if __name__ == "__main__":
    menu()

# %% [markdown]
# ## Parte I - Análisis de la solución
#
# Respondé las siguientes preguntas:

# %% [markdown]
# 1.1 **¿Qué estructuras de datos se utilizan para guardar los resultados a mostrar? ¿Te parece la más adecuada? Si no es así, ¿cuál usarías?**

# %% [markdown]
# **RTA.**
#
# En el *Ejercicio 1*, la estructura de datos utilizada para guardar los resultados es una lista. La misma se genera luego de filtrar el dataset a partir de ciertos criterios establecidos por la consigna (algunos correctamente y otros incorrectos/faltantes).
#
# Esta estructura no parece adecuada para resolver el enunciado, ya que devuelve una lista con nombres repetidos. Podríamos utilizar una estructura tipo <u>**set**</u> que elimina los repetidos, y hacer tener el conjunto de usuarios únicos que cumplan con las condiciones del filtro.
#
# En el *Ejercicio 2*, la estructura de datos utilizada vuelve a ser una lista, solo que esta vez se genera luego de que el usuario seleccione una opción del menú, llamando a la función del Ejercicio 1 y completando el parámetro que indica si debe retornarse en mayúsculas, minúsculas o en la forma tal cual aparacen en el dataset.
#
# De nuevo, la estructura no parece adecuada. Podríamos volver a utilizar un <u>**set**</u> sobre la lista cruda y después aplicar la función *.upper()* o *.lower()* según lo que decida el usuario en el menú. O bien, la función *usuarios_act1_turno_mañana* podría generar un <u>**diccionario**</u>, donde las claves sean las opciones del menú, y los valores sean los set obtenidos y pre-procesados (uno habiendo aplicado *.upper()*, otro habiendo aplicado *.lower()*, y otro con la versión *raw*).

# %% [markdown]
# 1.2. **Explicá detalladamente qué hace la función e indicá si te parece adecuada la forma de filtrar los datos JUSTIFICANDO la respuesta.**

# %% [markdown]
# **RTA.**
#
# La función *usuarios_act1_turno_mañana* recibe por parámetro:
# - un objeto **reader** de tipo csv.DictReader, y
# - un **formato**, opcional que puede ser "M" para mayúsculas, "m" para minúsculas o None (valor por defecto) para ver los datos tal cual aparecen en el dataset.
#
# La función realiza las siguientes operaciones:
#  - Crea una lista vacía *usuarios* para almacenar los resultados.
#  - Recorre fila por fila el objeto csv.DictReader y:
#    - Almacena en la variable *evento* el valor de "Nombre evento" en minúscula.
#    - Almacena en la variable *contexto* el valor de "Contexto del evento" en minúscula.
#    - Almacena en la variable *ip* el valor "Direccion IP".
#    - Si el string *"curso visto"* esta en la variable evento y la variable *ip* empieza con "163.10" (como empieza la dirección IP de la facultad):
#       - Almacena en la variable *usuario* el valor de "Nombre completo del usuario".
#       - Si **formato** = "M" aplica la función *.upper()* sobre *usuario*.
#       - Si **formato** = "M" aplica la función *.upper()* sobre *usuario*.
#       - Si **formato** = "M" aplica la función *.upper()* sobre *usuario*.
#       - Almacena en la lista *usuarios* la variable *usuario*.
#  - Devuelvee la lista de usuarios.
#
# Debajo se define otra función llamada *mas_popular* que no tiene que ver con la resolución del ejercicio.
#
# La forma de filtrar los datos:
# 1) Es incorrecta, porque estamos filtrando aquellos valores de *"Nombre evento"* que contengan *"curso visto"*, mientras que el enunciado pide que contenga *"Intento de cuestionario actualizado"*.
# 2) Está incompleta, porque además hay que filtrar aquellas filas para las cuales *"Contexto del evento"* contengan *"Cuestionario: ACT 1  - INFO - Turno MAÑANA".*
# 3) Es poco eficiente, ya que para cada fila primero se almacena el valor de las variables en minúscula y después se verifica si son iguales a los valores establecidos. Podríamos aprovechar la estructura csv.DictReader y el uso de la función *.filter()* para aplicar un filtro sobre todo el contenido del dataset, en lugar de utilizar tres variables independientes y aplicarlos sobre cada fila.

# %% [markdown]
# 1.3. **¿La solución del ejercicio 1 planteada resuelve la consigna?  Si hay un error, indicá cuál es el problema.**

# %% [markdown]
# **RTA.**
#
# Según lo explicado en los puntos anteriores, **el código no da error pero no resuelve el ejercicio**, ya que no filtra correctamente las filas según las condiciones del enunciado. Además, si bien se especifica, devuelve una lista con valores repetidos de usuario, no valores únicos.

# %% [markdown]
# 1.4. **La resolución del ejercicio 2, ¿podría simplificarse para evitar repetición de código?. Indicá cómo**

# %% [markdown]
# **RTA.**
#
# Si, podría simplificarse.
#
# 1) No hace falta volver a escribir la función *usuarios_act1_turno_mañana* si ya fue definida y ejecutada en una celda de código más arriba. Podríamos dejar solamente la función *menu* y el código se va a ejecutar igualmente.
# 2) Tampoco hace falta volver a importar los módulos *sys, os, csv y Path* si ya están importados en una celda de código más arriba.
# 3) En términos del flujo de trabajo, la función realiza lo siguiente:
#  - Utiliza un path absoluto para localizar el arhcivo.
#  - Abre el archivo y
#     - Utiliza la función *csv.DictReader* para leerlo en formato de diccionario, almacenándolo en la variable *reader*
#     - Solicita al usuario que ingrese por teclado un valor entre 1 y 4, donde 1 devuelve la lista de usuarios en mayúsculas, 2 en minúsculas, 3 tal como aparecen en el dataset y 4 para salir.
#     - Llama a la función del punto 1 *usuarios_act1_turno_mañana* y la ejecuta asignando un valor al parámetro *formato*, en función del valor ingresado por el usuario. Si el usuario ingresa 4 o cualquier otro valor, la función termina.
#     - Imprime la lista de usuarios, y en caso de no haber usuarios imprime "No se encontraron usuarios que cumplan las condiciones".
#
# Podríamos simplificar este flujo un poco más. Como mencioné en el primer punto, podríamos hacer que la función *usuarios_act1_turno_mañana* devuelva un <u>**diccionario**</u>, donde las claves sean las opciones del menú, y los valores sean los set obtenidos y pre-procesados (uno habiendo aplicado *.upper()*, otro habiendo aplicado *.lower()*, y otro con la versión *raw*). Podríamos hacer que la función *menu* se ejecute a posteriori, sin llamar a la función, sino llamando a su valor retornado. Entonces, cuando el usuario ingrese el valor, *menu* imprimirá los valores de la clave que el usuario ingresa por teclado. De esta manera además, evitaríamos que el archivo permanezca abierto para su lectura durante toda la ejecución.

# %% [markdown]
# 1.5 **¿Es correcto el manejo de archivos? ¿Se abre y se cierra correctamente?**

# %% [markdown]
# **RTA.**
#
# En la práctica, el Ejercicio 1 el manejo de los archivos funciona correctamente, pero <u>está sujeto a potenciales errores al no haber ningún manejo de excepciones</u>:
# 1) Al definirse una ruta estática, se asume que la carpeta existe con la dirección especificada. Debería especificarse una ubicación relativa de ser posible, o manejar la excepción de que el archivo no se encuentre.
# 2) Se asume que el archivo existe y se encuentra en la ubicación. Debería manejarse la excepción de que el archivo no se encuentre.
# 3) También se asume cuál es el formato de encoding y el delimiter.
# 4) Finalmente se asume que el csv tiene encabezados y que además tiene el formato esperado por el enunciado.
#
# Lo mismo aplica para el Ejercicio 2, con una observación adicional. El archivo se abre al inicio de la ejecución de *menu* y espera el input del usuario. Una vez recibido el valor, llama a la función *usuarios_act1_turno_mañana* o finaliza *menu* por ingresar un valor distinto a 1, 2 o 3. Recién al finalizar este bloque el archivo se cierra. Como consecuencia, <u>el archivo permanece abierto durante un período indefinido de tiempo de manera innecesaria</u>.

# %% [markdown]
# ## Parte II - Interacción con la IA
#
# Respondé las siguientes preguntas:

# %% [markdown]
# 2.1. **Mostrá una solución dada por una IA a este ejercicio y respondé:**

# %%
#Solución dada por la IA

import csv
import sys
import os
from pathlib import Path

def obtener_usuarios_act1(ruta_csv, formato=None):
    usuarios = set()  # evitar duplicados

    with open(ruta_csv, newline='', encoding='utf-8') as archivo:
        reader = csv.DictReader(archivo)

        for fila in reader:
            nombre_evento = fila.get("Nombre evento", "")
            contexto = fila.get("Contexto del evento", "")
            ip = fila.get("Dirección IP", "")
            usuario = fila.get("Nombre completo del usuario", "")  # ajustar si cambia

            # Validaciones (ojo: uso "in" como pide el enunciado)
            if (
                "Intento de cuestionario actualizado" in nombre_evento and
                "Cuestionario: ACT 1  - INFO - Turno MAÑANA" in contexto and
                ip.startswith("163.10")
            ):
                # Aplicar formato
                if formato == "M":
                    usuario = usuario.upper()
                elif formato == "m":
                    usuario = usuario.lower()

                usuarios.add(usuario)

    return list(usuarios)

def menu():
    sys.path.append(os.path.abspath(".."))
    ruta = Path.cwd()/'archivo'/'logs_catedra.csv'

    while True:
        print("\n--- MENÚ ---")
        print("1. Mostrar usuarios (mayúsculas)")
        print("2. Mostrar usuarios (minúsculas)")
        print("3. Mostrar usuarios (original)")
        print("4. Salir")

        opcion = input("Seleccione una opción: ")

        if opcion == "1":
            usuarios = obtener_usuarios_act1(ruta, "M")
            print("\nUsuarios:", usuarios)

        elif opcion == "2":
            usuarios = obtener_usuarios_act1(ruta, "m")
            print("\nUsuarios:", usuarios)

        elif opcion == "3":
            usuarios = obtener_usuarios_act1(ruta)
            print("\nUsuarios:", usuarios)

        elif opcion == "4":
            print("Fin del programa.")
            break

        else:
            print("Opción inválida.")

menu()

# %% [markdown]
# 2.2. **En la respuesta dada, ¿se incluyen funciones o métodos no dados por la cátedra?**

# %% [markdown]
# **RTA.**
#
# No, todas las funciones y métodos utilizados por la IA se vieron durante el curso.

# %% [markdown]
# 2.3.  **Según tu experiencia, ¿la solución brindada por la IA es mejor o no respecto a la dada. JUSTIFICÁ**

# %% [markdown]
# **RTA.**
#
# La solución dada por la IA es superior dado que repara muchos de los problemas comentados en la Parte I:
# - Utiliza *set()* para eliminar resultados duplicados.
# - Aplica correctamente todos los filtros que requiere el enunciado.
# - Declara las funciones una única vez.
# - Separa el funcionamiento del menú de la obtención de los datos, sin dejar el archivo abierto innecesariamente entre un paso y el otro.
#
# Esta solución aún podría mejorarse:
# - La función menú sigue ejecutándose en tanto no se selecciona la opción #4 "Salir".
# - Sigue sin haber manejo de excepciones (enumeradas en la Parte 1.5).

# %% [markdown]
# 2.4. **¿Qué IA utilizaste para esta parte?**

# %% [markdown]
# **RTA.**
#
# Para la resolución usé ChatGPT en su versión gratuita al 30/4/2026.

# %% [markdown]
# 2.5. **¿Usaste una IA para responder las consignas de la PARTE I?**

# %% [markdown]
# **RTA.**
#
# No, no use IA para responder las preguntas de la Parte I.
