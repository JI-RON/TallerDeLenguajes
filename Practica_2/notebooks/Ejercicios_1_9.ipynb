# %%
### IMPORTAMOS LAS DEPENDENCIAS NECESARIAS PARA REALIZAR LOS EJERCICIOS
import sys
sys.path.append('../src/')

# %% [markdown]
# ### Resolución del Ejercicio 1

# %%
### DATOS PROVISTOS POR EL ENUNCIADO

text = """Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way to do it.
Although that way may not be obvious at first unless you're Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good idea.
Namespaces are one honking great idea -- let's do more of those!"""

# %%
from helpers_1_9 import ejercicio_1_contador, ejercicio_1_encima_promedio

cantidad_lineas, cantidad_palabras, palabras_por_linea = ejercicio_1_contador(text)

print(f'Cantidad de lineas: {cantidad_lineas}')
print(f'Cantidad de palabras: {cantidad_palabras}')
print(f'Promedio de palabras por linea: {palabras_por_linea}')
print()

ejercicio_1_encima_promedio(text,palabras_por_linea)
# Out:
# Cantidad de lineas: 19
# Cantidad de palabras: 137
# Promedio de palabras por linea: 7.21
#
# Líneas por encima del promedio (7.21 palabras):
# - Special cases aren't special enough to break the rules. (9 palabras)
# - In the face of ambiguity, refuse the temptation to guess. (10 palabras)
# - There should be one-- and preferably only one --obvious way to do it. (13 palabras)
# - Although that way may not be obvious at first unless you're Dutch. (12 palabras)
# - Although never is often better than *right* now. (8 palabras)
# - If the implementation is hard to explain, it's a bad idea. (11 palabras)
# - If the implementation is easy to explain, it may be a good idea. (13 palabras)
# - Namespaces are one honking great idea -- let's do more of those! (12 palabras)

# %% [markdown]
# ### Resolución del Ejercicio 2

# %%
### DATOS PROVISTOS POR EL ENUNCIADO

playlist = [
{"title": "Bohemian Rhapsody", "duration": "5:55"},
{"title": "Hotel California", "duration": "6:30"},
{"title": "Stairway to Heaven", "duration": "8:02"},
{"title": "Imagine", "duration": "3:07"},
{"title": "Smells Like Teen Spirit", "duration": "5:01"},
{"title": "Billie Jean", "duration": "4:54"},
{"title": "Hey Jude", "duration": "7:11"},
{"title": "Like a Rolling Stone", "duration": "6:13"},
]

# %%
from helpers_1_9 import ejercicio_2

duracion_total,linea_max,linea_min = ejercicio_2(playlist)

print(duracion_total)
print(f'Canción más larga: "{playlist[linea_max]["title"]}", ({playlist[linea_max]["duration"]})')
print(f'Canción más corta: "{playlist[linea_min]["title"]}", #({playlist[linea_min]["duration"]})')
# Out:
# Duración total: 46m 53s
# Canción más larga: "Stairway to Heaven", (8:02)
# Canción más corta: "Imagine", #(3:07)

# %% [markdown]
# ### Resolución del Ejercicio 3

# %%
### DATOS PROVISTOS POR EL ENUNCIADO

review = """La película sigue a un grupo de astronautas que 
viajan a Marte
en una misión de rescate. El capitán Torres lidera al equipo 
a través
de tormentas solares y fallos en el sistema de navegación. Al 
llegar
a Marte descubren que la base está abandonada y los 
suministros
destruidos. Torres decide sacrificar la nave nodriza para 
salvar
al equipo y logran volver a la Tierra en una cápsula de 
emergencia.
El final revela que Torres sobrevivió gracias a un pasaje 
secreto."""

# %%
from helpers_1_9 import ejercicio_3

ejercicio_3(review)
# Out:
# 'La película sigue a un grupo de astronautas que  viajan a ***** en una misión de rescate. El capitán Torres lidera al equipo  a través de tormentas solares y fallos en el sistema de navegación. Al  llegar a ***** descubren que la base está abandonada y los  suministros destruidos. Torres decide sacrificar la nave nodriza para  salvar al equipo y logran volver a la Tierra en una cápsula de  emergencia. El final revela que Torres sobrevivió gracias a un pasaje  secreto.'

# %% [markdown]
# ### Resolución del Ejercicio 4

# %%
### DATOS PROVISTOS POR EL ENUNCIADO

# Valide una dirección de email ingresada por el usuario con los siguientes
# criterios:
# -Contiene exactamente un @.
# -Tiene al menos un carácter antes del @.
# -Tiene al menos un punto (.) después del @.
# -No empieza ni termina con @ ni con ..
# -La parte después del último punto tiene al menos 2 caracteres (el dominio).

# %%
from helpers_1_9 import ejercicio_4

ejercicio_4()
# Out:
# El mail no es válido.

# %% [markdown]
# ### Resolución del Ejercicio 5

# %%
from helpers_1_9 import ejercicio_5

ejercicio_5()
# Out:
# 'El precio a pagar por el paquete es: $500'

# %% [markdown]
# ### Resolución del Ejercicio 6

# %%
### DATOS PROVISTOS POR EL ENUNCIADO

posts = [
"Arrancando el lunes con energía #Motivación #NuevaSemana",
"Terminé mi primer proyecto en Python #Python #Programación #OrgullosoDeMi",
"No puedo creer el final de la serie #SinSpoilers #SerieAdicta",
"Nuevo video en el canal sobre #InteligenciaArtificial y #Python",
"Entrenamiento de hoy completado #Fitness #Motivación #NoPainNoGain",
"Leyendo sobre #InteligenciaArtificial y el futuro del trabajo #Tecnología",
"Arranqué a estudiar #Programación por mi cuenta #Python #Autodidacta",
"Finde de lluvia, maratón de series #SerieAdicta #Relax","Workshop de #InteligenciaArtificial en la universidad #Tecnología #Programación"
]

# %%
from helpers_1_9 import ejercicio_6

ranking = ejercicio_6(posts)

print('Hashtags trending (más de una aparición):')
for item in ranking:
    if item[1] > 1:
        print('  ',item[0],':',item[1])

print()
print('Total de hashtags únicos:',len(ranking))
# Out:
# Hashtags trending (más de una aparición):
#    #Python : 3
#    #Programación : 3
#    #InteligenciaArtificial : 3
#    #Motivación : 2
#    #SerieAdicta : 2
#    #Tecnología : 2
#
# Total de hashtags únicos: 13

# %% [markdown]
# ### Resolución del Ejercicio 7

# %%
from helpers_1_9 import ejercicio_7

ejercicio_7()
# Out:
# Sorteo de amigo invisible:
#      a  →  b
#      b  →  c
#      c  →  a
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 from helpers_1_9 import ejercicio_7
# ----> 3 ejercicio_7()
#
# File c:\Users\juani\OneDrive\Desktop\Taller de Lenguajes\GitHub\TallerDeLenguajes\Practica_2\notebooks\../src\helpers_1_9.py:229, in ejercicio_7()
#     226     participantes = lista.split(', ')
#     228 print('Sorteo de amigo invisible:')
# --> 229 return ejercicio_7_sortea_pares(participantes)
#
# File c:\Users\juani\OneDrive\Desktop\Taller de Lenguajes\GitHub\TallerDeLenguajes\Practica_2\notebooks\../src\helpers_1_9.py:210, in ejercicio_7_sortea_pares(lista_de_participantes)
#     208 participante_2 = random.choice(recibe_regalo)
#     209 while participante_1 == participante_2:
# --> 210     participante_2 = random.choice(recibe_regalo)
# ...

# %% [markdown]
# ### Resolución del Ejercicio 8

# %%
from helpers_1_9 import ejercicio_8

mensaje, mensaje_cifrado = ejercicio_8()

print(f'Mensaje cifrado: {mensaje_cifrado}')
print(f'Mensaje descifrado: {mensaje}')
# Out:
# Mensaje cifrado: Def...Krod!
# Mensaje descifrado: Abc...Hola!

# %% [markdown]
# ### Resolución del Ejercicio 9

# %%
### DATOS PROVISTOS POR EL ENUNCIADO

students = [
    {"name": "  Ana García ", "grade": "8", "status":"aprobado"},
    {"name": "pedro lópez", "grade": "4", "status":"DESAPROBADO"},
    {"name": "MARÍA FERNÁNDEZ", "grade": "10", "status":"Aprobado"},
    {"name": "ana garcía", "grade": "9", "status":"aprobado"},
    {"name": None, "grade": "7", "status": "aprobado"},
    {"name": "Luis Martínez  ", "grade": None, "status":"aprobado"},
    {"name": " carlos RUIZ", "grade": "6", "status":"aprobado"},
    {"name": "PEDRO LÓPEZ ", "grade": "3", "status":"desaprobado"},
    {"name": "  ", "grade": "5", "status": "aprobado"},
    {"name": "María Fernández", "grade": "7", "status":"APROBADO"},
    {"name": "Sofía Torres", "grade": "9", "status":"Aprobado"},
    {"name": "  sofía torres ", "grade": "8", "status":"aprobado"},
    {"name": "Carlos Ruiz", "grade": "6", "status":"APROBADO"},
    {"name": "Roberto Díaz", "grade": "absent", "status":"ausente"},
    {"name": "roberto díaz", "grade": "", "status":"Ausente"},
    {"name": None, "grade": None, "status": None},
    {"name": "Laura Méndez", "grade": "7", "status":"aprobado"},
    {"name": "  laura méndez", "grade": "8", "status":"Aprobado"},
    {"name": "GABRIELA RÍOS", "grade": "5", "status":"aprobado"},
    {"name": "gabriela ríos ", "grade": "4", "status":"Desaprobado"},
]

# Debe realizar las siguientes operaciones:
# -Eliminar registros con nombre nulo, vacío o solo espacios.
# -Eliminar registros con nota nula, vacía o no numérica (como "absent").
# -Normalizar nombres a formato título y estados a formato título.
# -Eliminar duplicados por nombre, quedándose con la nota más alta de cada alumno.
# -Ordenar alfabéticamente por nombre.

# %%
from helpers_1_9 import ejercicio_9

ejercicio_9(students)
# Out:
# Registros limpios de alumnos:
# Nombre          Nota  Estado
# -----------------------------------
# Ana García      9     Aprobado
# Carlos Ruiz     6     Aprobado
# Gabriela Ríos   5     Aprobado
# Laura Méndez    8     Aprobado
# María Fernández 7     Aprobado
# Pedro López     4     Desaprobado
# Sofía Torres    9     Aprobado
